# %% [markdown]
# <a href="https://colab.research.google.com/github/Laureoby/audible_dataset1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
df = pd.read_csv("/content/drive/MyDrive/audible_uncleaned.csv")

# %%
df.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars   price
# 0     5 out of 5 stars34 ratings  468.00
# 1   4.5 out of 5 stars41 ratings  820.00
# 2   4.5 out of 5 stars38 ratings  410.00
# 3   4.5 out of 5 stars12 ratings  615.00
# 4  4.5 out of 5 stars181 ratings  820.00

# %%
df.isna().sum()
# Out:
# name           0
# author         0
# narrator       0
# time           0
# releasedate    0
# language       0
# stars          0
# price          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['author'] = df['author'].str.replace('Writtenby:', "")
df
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      Narratedby:JesseBernstein              10 hrs    13-01-10  English
# ...                          ...                 ...         ...      ...
# 87484    Narratedby:ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      Narratedby:RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     Narratedby:AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     Narratedby:FleetCooper     6 hrs and 1 min    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %%
df['narrator'] = df['narrator'].str.replace('Narratedby:', "")
df
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator                time releasedate language  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      JesseBernstein              10 hrs    13-01-10  English
# ...               ...                 ...         ...      ...
# 87484    ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     FleetCooper     6 hrs and 1 min    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %%
def split_names(data, column_name):
    pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    data[column_name] = data[column_name].apply(lambda x: ' '.join(pattern.split(x, 1)))
    return data
df = split_names(df, 'author')
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#              narrator                time releasedate language  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      JesseBernstein              10 hrs    13-01-10  English
# ...               ...                 ...         ...      ...
# 87484    ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     FleetCooper     6 hrs and 1 min    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %%
df = split_names(df, 'narrator')
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator                time releasedate language  \
# 0          Bill Lobely   2 hrs and 20 mins    04-08-08  English
# 1       Robbie Daymond   13 hrs and 8 mins    01-05-18  English
# 2          Dan Russell    2 hrs and 3 mins    06-11-20  English
# 3      Soneela Nankani  11 hrs and 16 mins    05-10-21  English
# 4      Jesse Bernstein              10 hrs    13-01-10  English
# ...                ...                 ...         ...      ...
# 87484    Chris Stewart   7 hrs and 34 mins    09-03-17  English
# 87485      Robert Fass   10 hrs and 7 mins    21-02-17  English
# 87486       Flo Gibson   19 hrs and 4 mins    30-12-16  English
# 87487     Anton Lesser    4 hrs and 8 mins    23-02-11  English
# 87488     Fleet Cooper     6 hrs and 1 min    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %%
#Now we work on time column
df['time'] = df['time'].astype(str)
hours = df['time'].str.extract(r'(\d+)\s*hrs').astype(float)
minutes = df['time'].str.extract(r'(\d+)\s*mins').astype(float)
hours_in_min = hours * 60
total_min = hours_in_min.fillna(0) + minutes.fillna(0)
df['time'] = total_min
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator    time releasedate language  \
# 0          Bill Lobely   140.0    04-08-08  English
# 1       Robbie Daymond   788.0    01-05-18  English
# 2          Dan Russell   123.0    06-11-20  English
# 3      Soneela Nankani   676.0    05-10-21  English
# 4      Jesse Bernstein   600.0    13-01-10  English
# ...                ...     ...         ...      ...
# 87484    Chris Stewart   454.0    09-03-17  English
# 87485      Robert Fass   607.0    21-02-17  English
# 87486       Flo Gibson  1144.0    30-12-16  English
# 87487     Anton Lesser   248.0    23-02-11  English
# 87488     Fleet Cooper   360.0    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %%
df['ratings'] = df['stars']
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator    time releasedate language  \
# 0          Bill Lobely   140.0    04-08-08  English
# 1       Robbie Daymond   788.0    01-05-18  English
# 2          Dan Russell   123.0    06-11-20  English
# 3      Soneela Nankani   676.0    05-10-21  English
# 4      Jesse Bernstein   600.0    13-01-10  English
# ...                ...     ...         ...      ...
# 87484    Chris Stewart   454.0    09-03-17  English
# 87485      Robert Fass   607.0    21-02-17  English
# 87486       Flo Gibson  1144.0    30-12-16  English
# 87487     Anton Lesser   248.0    23-02-11  English
# 87488     Fleet Cooper   360.0    07-03-17  English
#
#                                stars   price                        ratings
# 0         5 out of 5 stars34 ratings  468.00     5 out of 5 stars34 ratings
# 1       4.5 out of 5 stars41 ratings  820.00   4.5 out of 5 stars41 ratings
# 2       4.5 out of 5 stars38 ratings  410.00   4.5 out of 5 stars38 ratings
# 3       4.5 out of 5 stars12 ratings  615.00   4.5 out of 5 stars12 ratings
# 4      4.5 out of 5 stars181 ratings  820.00  4.5 out of 5 stars181 ratings
# ...                              ...     ...                            ...
# 87484                  Not rated yet  596.00                  Not rated yet
# 87485                  Not rated yet  820.00                  Not rated yet
# 87486                  Not rated yet  938.00                  Not rated yet
# 87487                  Not rated yet  680.00                  Not rated yet
# 87488                  Not rated yet  569.00                  Not rated yet
#
# [87489 rows x 9 columns]

# %%
#we keep just stars informations in stars column
df['stars'] = df['stars'].str.extract(r'(\d+\.\d+|\d+)')
df['stars']
# Out:
# 0          5
# 1        4.5
# 2        4.5
# 3        4.5
# 4        4.5
#         ...
# 87484    NaN
# 87485    NaN
# 87486    NaN
# 87487    NaN
# 87488    NaN
# Name: stars, Length: 87489, dtype: object

# %%
df['stars'].fillna(value=0.0, inplace=True)
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator    time releasedate language stars   price  \
# 0          Bill Lobely   140.0    04-08-08  English     5  468.00
# 1       Robbie Daymond   788.0    01-05-18  English   4.5  820.00
# 2          Dan Russell   123.0    06-11-20  English   4.5  410.00
# 3      Soneela Nankani   676.0    05-10-21  English   4.5  615.00
# 4      Jesse Bernstein   600.0    13-01-10  English   4.5  820.00
# ...                ...     ...         ...      ...   ...     ...
# 87484    Chris Stewart   454.0    09-03-17  English   0.0  596.00
# 87485      Robert Fass   607.0    21-02-17  English   0.0  820.00
# 87486       Flo Gibson  1144.0    30-12-16  English   0.0  938.00
# 87487     Anton Lesser   248.0    23-02-11  English   0.0  680.00
# 87488     Fleet Cooper   360.0    07-03-17  English   0.0  569.00
#
#                              ratings
# 0         5 out of 5 stars34 ratings
# 1       4.5 out of 5 stars41 ratings
# 2       4.5 out of 5 stars38 ratings
# 3       4.5 out of 5 stars12 ratings
# 4      4.5 out of 5 stars181 ratings
# ...                              ...
# 87484                  Not rated yet
# 87485                  Not rated yet
# 87486                  Not rated yet
# 87487                  Not rated yet
# 87488                  Not rated yet
#
# [87489 rows x 9 columns]

# %%
#Now we select ratings in ratings's column. We keep just stars informations in stars column
df['ratings'] = df['ratings'].str.extract(r'(\d+) ratings')
df['ratings']
# Out:
# 0         34
# 1         41
# 2         38
# 3         12
# 4        181
#         ...
# 87484    NaN
# 87485    NaN
# 87486    NaN
# 87487    NaN
# 87488    NaN
# Name: ratings, Length: 87489, dtype: object

# %%
df['ratings'].fillna(value=0.0, inplace=True)
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator    time releasedate language stars   price ratings
# 0          Bill Lobely   140.0    04-08-08  English     5  468.00      34
# 1       Robbie Daymond   788.0    01-05-18  English   4.5  820.00      41
# 2          Dan Russell   123.0    06-11-20  English   4.5  410.00      38
# 3      Soneela Nankani   676.0    05-10-21  English   4.5  615.00      12
# 4      Jesse Bernstein   600.0    13-01-10  English   4.5  820.00     181
# ...                ...     ...         ...      ...   ...     ...     ...
# 87484    Chris Stewart   454.0    09-03-17  English   0.0  596.00     0.0
# 87485      Robert Fass   607.0    21-02-17  English   0.0  820.00     0.0
# 87486       Flo Gibson  1144.0    30-12-16  English   0.0  938.00     0.0
# 87487     Anton Lesser   248.0    23-02-11  English   0.0  680.00     0.0
# 87488     Fleet Cooper   360.0    07-03-17  English   0.0  569.00     0.0
#
# [87489 rows x 9 columns]

# %%
df.dtypes
# Out:
# name            object
# author          object
# narrator        object
# time           float64
# releasedate     object
# language        object
# stars           object
# price           object
# ratings         object
# dtype: object

# %%
df['time']
# Out:
# 0         140.0
# 1         788.0
# 2         123.0
# 3         676.0
# 4         600.0
#           ...
# 87484     454.0
# 87485     607.0
# 87486    1144.0
# 87487     248.0
# 87488     360.0
# Name: time, Length: 87489, dtype: float64

# %%
#Now we work on df visualization. We want to know which movies take at lot of time
movies_time = df.groupby('name')['time'].mean().sort_values(ascending=False)
#We select ten movies which are highest time
top_movies = movies_time.head(5).index
#We create diagram
plt.figure(figsize=(10, 6))
plt.pie(movies_time[top_movies], labels=top_movies, autopct='%1.1f%%')
plt.title('Movies with highest time')
plt.axis('equal') #we want to obtain perfect circle
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37428 (\N{CJK UNIFIED IDEOGRAPH-9234}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26408 (\N{CJK UNIFIED IDEOGRAPH-6728}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19977 (\N{CJK UNIFIED IDEOGRAPH-4E09}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21513 (\N{CJK UNIFIED IDEOGRAPH-5409}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31461 (\N{CJK UNIFIED IDEOGRAPH-7AE5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35441 (\N{CJK UNIFIED IDEOGRAPH-8A71}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20840 (\N{CJK UNIFIED IDEOGRAPH-5168}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38598 (\N{CJK UNIFIED IDEOGRAPH-96C6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21454 (\N{CJK UNIFIED IDEOGRAPH-53CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37682 (\N{CJK UNIFIED IDEOGRAPH-9332}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#we print histogram of language column
plt.figure(figsize=(8,6))
sns.countplot(x=df['language'])
plt.title('Distribution of language Values')
plt.show()

# %%
#we print histogram of language column
plt.figure(figsize=(8,6))
sns.countplot(x=df['language'])
plt.title('Distribution of language Values')
plt.xticks(rotation=90)
plt.show()

# %%
#We convert price column into numeric values
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
movies_price = df.groupby('name')['price'].mean().sort_values(ascending=False)
top_movies = movies_price.head(10)

plt.figure(figsize=(10, 6))
plt.scatter(top_movies.index, top_movies.values)
plt.title('Top 10 Movies by Average Revenue')
plt.xlabel('Movie Name')
plt.ylabel('Average Revenue')
plt.xticks(rotation=45)
plt.show()
